# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.title("Mi primera gráfica")
plt.xlabel("Etiqueta eje x")
plt.ylabel("Etiqueta eje y")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot([1,2,3,4], [1,4,9,16])
plt.title("Mi primera gráfica")
plt.xlabel("Etiqueta eje x")
plt.ylabel("Etiqueta eje y")
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], "go")
plt.title("Mi primera gráfica")
plt.xlabel("Etiqueta eje x")
plt.ylabel("Etiqueta eje y")
plt.show()

# %%
x = np.arange(1,5)
y = x**3
plt.plot([1,2,3,4], [1,4,9,16], 'go', x, y, 'r^')
plt.title("Primera gráfica")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.show()

# %% [markdown]
#   ### Ejercicios

# %% [markdown]
# 1.-

# %%
data = np.loadtxt("numpy_values_to_load.txt", delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-b216b82ed7ca> in <module>
# ----> 1 data = np.loadtxt("numpy_values_to_load.txt", delimiter=",")
#
# ~/Library/Python/3.7/lib/python/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     966             fname = os_fspath(fname)
#     967         if _is_string_like(fname):
# --> 968             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     969             fencoding = getattr(fh, 'encoding', 'latin1')
#     970             fh = iter(fh)
#
# ~/Library/Python/3.7/lib/python/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/Library/Python/3.7/lib/python/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: numpy_values_to_load.txt not found.
